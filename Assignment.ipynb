# %%
###
# This is for using in ipython(not important)

# coding: utf-8
#get_ipython().magic('load ai_hw_1.py')
# %load ai_hw_1.py

###

###
# you can import this file in jupyter with
# load ai_hw_2.py OR
# from ai_hw_2 import *
###
from nltk.book import *
#text1
from nltk.corpus import gutenberg
gutenberg.fileids()

# load book from gutenberg
emma = gutenberg.words('carroll-alice.txt')
emma
gutenberg.fileids()

# Number of sentences
num_sents = len(gutenberg.sents('carroll-alice.txt'))
print('Number of sentences:',num_sents)

# sentences is a list of sentences in the book
sentences = gutenberg.sents('carroll-alice.txt')
sentences
# Number of sentences in the book
len(sentences)
sent_len = []
    
#for line in range(0, len(sentences)):
#    sent_len = len(sentences [line])
    
# number of sentences    
#sent_len
#len(sentences)

# range from 0 to no. of sentences
#range(0, len(sentences))
    
    
    
#sent_len = []

# type of sent_len is list
type(sent_len)

# trying to append numbers to sent_len
#sent_len.append(1)
#sent_len.append(2)


#type(line)
#sent_len = []
#sent_len
#line
#sentences
#line
#sent_len
#sentences[0]
#len(sentences[0])
#new = []
#new.append(len(sentences[0]))
#new.append(len(sentences[1]))
#new
#line
#sent_len


# Adding length of each sentence to the sent_len list
for line in range(0, len(sentences)):
    sent_len.append(len(sentences[line]))
    
sent_len

# Longest sentence
max(sent_len)

# Finding the longest sentence by its index
import numpy as np
ind = np.argmax(sent_len)
# index of the longest sentence
ind
sentences[ind]

# grouping sentences of similar length
from collections import Counter
occurences = Counter(sent_len)
occurences
#get_ipython().magic('save ai_hw_1 1-61')
#ipython -i [filename]
#sent_len
# arranging list of 'sentence lenths' in ascending order
sort_sent_len = sorted(sent_len)
sort_sent_len
#sent_len
#sort_sent_len

# now grouping sentences of similar length in ascending order
sort_occ = Counter(sort_sent_len)
sort_occ

# for plotting the histogram of grouped sentence lengths in ascending order
import numpy as np
import matplotlib.pyplot as plt
labels, values = zip(*sort_occ.items())
indexes = np.arange(len(labels))
width = 0.5
plt.bar(indexes, values, width)
plt.xticks(indexes + width * 0.5, labels)
plt.tight_layout()
#plt.show()
#https://stackoverflow.com/questions/19198920/using-counter-in-python-to-build-histogram
# Out:
# Number of sentences: 1703

# %%
sentences[ind]
# Out:
# ['Hardly',
#  'knowing',
#  'what',
#  'she',
#  'did',
#  ',',
#  'she',
#  'picked',
#  'up',
#  'a',
#  'little',
#  'bit',
#  'of',
#  'stick',
#  ',',
#  'and',
#  'held',
#  'it',
#  'out',
#  'to',
#  'the',
#  'puppy',
#  ';',
#  'whereupon',
#  'the',
#  'puppy',
#  'jumped',
#  'into',
#  'the',
#  'air',
#  'off',
#  'all',
#  'its',
#  'feet',
#  'at',
#  'once',
#  ',',
#  'with',
#  'a',
#  'yelp',
#  'of',
#  'delight',
#  ',',
#  'and',
#  'rushed',
#  'at',
#  'the',
#  'stick',
#  ',',
#  'and',
#  'made',
#  'believe',
#  'to',
#  'worry',
#  'it',
#  ';',
#  'then',
#  'Alice',
#  'dodged',
#  'behind',
#  'a',
#  'great',
#  'thistle',
#  ',',
#  'to',
#  'keep',
#  'herself',
#  'from',
#  'being',
#  'run',
#  'over',
#  ';',
#  'and',
#  'the',
#  'moment',
#  'she',
#  'appeared',
#  'on',
#  'the',
#  'other',
#  'side',
#  ',',
#  'the',
#  'puppy',
#  'made',
#  'another',
#  'rush',
#  'at',
#  'the',
#  'stick',
#  ',',
#  'and',
#  'tumbled',
#  'head',
#  'over',
#  'heels',
#  'in',
#  'its',
#  'hurry',
#  'to',
#  'get',
#  'hold',
#  'of',
#  'it',
#  ';',
#  'then',
#  'Alice',
#  ',',
#  'thinking',
#  'it',
#  'was',
#  'very',
#  'like',
#  'having',
#  'a',
#  'game',
#  'of',
#  'play',
#  'with',
#  'a',
#  'cart',
#  '-',
#  'horse',
#  ',',
#  'and',
#  'expecting',
#  'every',
#  'moment',
#  'to',
#  'be',
#  'trampled',
#  'under',
#  'its',
#  'feet',
#  ',',
#  'ran',
#  'round',
#  'the',
#  'thistle',
#  'again',
#  ';',
#  'then',
#  'the',
#  'puppy',
#  'began',
#  'a',
#  'series',
#  'of',
#  'short',
#  'charges',
#  'at',
#  'the',
#  'stick',
#  ',',
#  'running',
#  'a',
#  'very',
#  'little',
#  'way',
#  'forwards',
#  'each',
#  'time',
#  'and',
#  'a',
#  'long',
#  'way',
#  'back',
#  ',',
#  'and',
#  'barking',
#  'hoarsely',
#  'all',
#  'the',
#  'while',
#  ',',
#  'till',
#  'at',
#  'last',
#  'it',
#  'sat',
#  'down',
#  'a',
#  'good',
#  'way',
#  'off',
#  ',',
#  'panting',
#  ',',
#  'with',
#  'its',
#  'tongue',
#  'hanging',
#  'out',
#  'of',
#  'its',
#  'mouth',
#  ',',
#  'and',
#  'its',
#  'great',
#  'eyes',
#  'half',
#  'shut',
#  '.']

# %%
from spacy.en import English
nlp = English()
doc = nlp(str(sentences[ind]))
for sent in doc.sents:
    for token in sent:
        if token.is_alpha:
            print (token.orth_, token.tag_, token.head.lemma_)
# Out:
# Hardly RB jump
# knowing VBG jump
# what WP know
# she PRP jump
# did VBD -PRON-
# she PRP jump
# picked VBN jump
# up RB pick
# a DT bit
# little JJ bit
# bit NN pick
# of IN bit
# stick NN pick
# and CC pick
# held VBN pick
# it PRP hold
# out IN hold
# to IN hold
# the DT puppy
# puppy NN pick
# whereupon UH pick
# the DT puppy
# puppy NN jump
# jumped VBD jump
# into IN jump
# the DT jump
# air NN rush
# off IN air
# all DT air
# its PRP$ delight
# feet NNS -PRON-
# at IN foot
# once RB foot
# with IN '
# a DT yelp
# yelp NN foot
# of IN yelp
# delight NN all
# and CC air
# rushed VBD jump
# at IN rush
# the DT rush
# stick NN rush
# and CC stick
# made VBD rush
# believe VB make
# to IN believe
# worry NN make
# it PRP make
# then RB make
# Alice NNP be
# dodged VBD alice
# behind IN dodge
# a DT dodge
# great JJ be
# thistle NN great
# to IN thistle
# keep VB great
# herself PRP keep
# from IN keep
# being VBG keep
# run VB keep
# over IN run
# and CC keep
# the DT moment
# moment NN keep
# she PRP keep
# appeared VBD be
# on IN '
# the DT make
# other JJ the
# side NN other
# the DT puppy
# puppy NN other
# made VBD be
# another DT make
# rush NN another
# at IN rush
# the DT stick
# stick NN another
# and CC another
# tumbled VBD ,
# head NN tumble
# over IN head
# heels NNS head
# in IN heel
# its PRP$ hold
# hurry NN -PRON-
# to IN hurry
# get VB -PRON-
# hold NN tumble
# of IN hold
# it PRP tumble
# then RB tumble
# Alice NNP be
# thinking VBG alice
# it PRP think
# was VBD make
# very RB be
# like IN '
# having VBG '
# a DT game
# game NN have
# of IN game
# play NN game
# with IN game
# a DT cart
# cart NN have
# horse NN cart
# and CC cart
# expecting VBG cart
# every DT moment
# moment NN expect
# to IN moment
# be VB have
# trampled VBD be
# under IN trample
# its PRP$ foot
# feet NNS trample
# ran VBD trample
# round NN run
# the DT run
# thistle NN the
# again RB the
# then RB begin
# the DT puppy
# puppy NN begin
# began VBD run
# a DT begin
# series NN begin
# of IN series
# short JJ charge
# charges NNS series
# at IN charge
# the DT stick
# stick NN begin
# running VBG begin
# a DT run
# very RB little
# little JJ begin
# way NN begin
# forwards NNS begin
# each DT begin
# time NN each
# and CC time
# a DT way
# long RB way
# way NN each
# back RB way
# and CC way
# barking VBG way
# hoarsely RB bark
# all DT hoarsely
# the DT all
# while IN all
# till IN '
# at IN '
# last JJ till
# it PRP sit
# sat VBD last
# down IN sit
# a DT way
# good JJ way
# way NN sit
# off IN sit
# panting VBG sit
# with IN pant
# its PRP$ -PRON-
# tongue NN -PRON-
# hanging VBG tongue
# out IN hang
# of IN out
# its PRP$ pant
# mouth NN -PRON-
# and CC -PRON-
# its PRP$ -PRON-
# great JJ -PRON-
# eyes NNS great
# half NN great
# shut VBD -PRON-

# %%
from nltk import Tree
def to_nltk_tree(node):
    if node.n_lefts + node.n_rights > 0:
        return Tree(node.orth_, [to_nltk_tree(child) for child in node.children])
    else:
        return node.orth_


[to_nltk_tree(sent.root).pretty_print() for sent in doc.sents]
# Out:
#                                                                                                                                                   jumped
#   __________________________________________________________________________________________________________________________________________________|____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
#  |   |   |   |   |   |   |   |   |   |    |               |                          |                   |                                                                                                                     |                                                                                                                                             |            |                |       |        |                                                                                                                                  rushed
#  |   |   |   |   |   |   |   |   |   |    |               |                          |                   |                                                                                                                     |                                                                                                                                             |            |                |       |        |    ________________________________________________________________________________________________________________________________|_______________________________________________________________________________________________________________________________________________________________________________________________________________________
#  |   |   |   |   |   |   |   |   |   |    |               |                          |                   |                                                                                                                     |                                                                                                                                             |            |                |       |        |   |   |   |   |                                                                                                   |                                                                                                                                  |           |                        |                                                               made
#  |   |   |   |   |   |   |   |   |   |    |               |                          |                   |                                                                                                                     |                                                                                                                                             |            |                |       |        |   |   |   |   |                                                                                                   |                                                                                                                                  |           |                        |                     ___________________________________________|__________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
#  |   |   |   |   |   |   |   |   |   |    |               |                          |                   |                                                                                                                     |                                                                                                                                             |            |                |       |        |   |   |   |   |                                                                                                   |                                                                                                                                  |           |                        |                    |   |   |   |   |   |   |   |   |   |   |                  |                      |    |   |                                                                                                                                                                                                          was
#  |   |   |   |   |   |   |   |   |   |    |               |                          |                   |                                                                                                                     |                                                                                                                                             |            |                |       |        |   |   |   |   |                                                                                                   |                                                                                                                                  |           |                        |                    |   |   |   |   |   |   |   |   |   |   |                  |                      |    |   |     ______________________________________________________________________________________________________________________________________________________________________________________________________|________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
#  |   |   |   |   |   |   |   |   |   |    |               |                          |                   |                                                                                                                     |                                                                                                                                             |            |                |       |        |   |   |   |   |                                                                                                   |                                                                                                                                  |           |                        |                    |   |   |   |   |   |   |   |   |   |   |                  |                      |    |   |    |   |   |   |   |   |   |                        |                                                                                                                                        |                                                                                                                         |                                                                                                                                                                                                      |                                                                                                                                                                                                                                 |                                                         very
#  |   |   |   |   |   |   |   |   |   |    |               |                          |                   |                                                                                                                     |                                                                                                                                             |            |                |       |        |   |   |   |   |                                                                                                   |                                                                                                                                  |           |                        |                    |   |   |   |   |   |   |   |   |   |   |                  |                      |    |   |    |   |   |   |   |   |   |                        |                                                                                                                                        |                                                                                                                         |                                                                                                                                                                                                      |                                                                                                                                                                                                                                 |                                      ____________________|____________________
#  |   |   |   |   |   |   |   |   |   |    |               |                          |                   |                                                                                                                     |                                                                                                                                             |            |                |       |        |   |   |   |   |                                                                                                   |                                                                                                                                  |           |                        |                    |   |   |   |   |   |   |   |   |   |   |                  |                      |    |   |    |   |   |   |   |   |   |                        |                                                                                                                                        |                                                                                                                         |                                                                                                                                                                                                      |                                                                                                                                                                                                                                 |                                     |                                         ,
#  |   |   |   |   |   |   |   |   |   |    |               |                          |                   |                                                                                                                     |                                                                                                                                             |            |                |       |        |   |   |   |   |                                                                                                   |                                                                                                                                  |           |                        |                    |   |   |   |   |   |   |   |   |   |   |                  |                      |    |   |    |   |   |   |   |   |   |                        |                                                                                                                                        |                                                                                                                         |                                                                                                                                                                                                      |                                                                                                                                                                                                                                 |                                     |                                         |
#  |   |   |   |   |   |   |   |   |   |    |               |                          |                   |                                                                                                                     |                                                                                                                                             |            |                |       |        |   |   |   |   |                                                                                                   |                                                                                                                                  |           |                        |                    |   |   |   |   |   |   |   |   |   |   |                  |                      |    |   |    |   |   |   |   |   |   |                        |                                                                                                                                        |                                                                                                                         |                                                                                                                                                                                                      |                                                                                                                                                                                                                                 |                                     |                                         '
#  |   |   |   |   |   |   |   |   |   |    |               |                          |                   |                                                                                                                     |                                                                                                                                             |            |                |       |        |   |   |   |   |                                                                                                   |                                                                                                                                  |           |                        |                    |   |   |   |   |   |   |   |   |   |   |                  |                      |    |   |    |   |   |   |   |   |   |                        |                                                                                                                                        |                                                                                                                         |                                                                                                                                                                                                      |                                                                                                                                                                                                                                 |                                     |        _________________________________|__________________________________________
#  |   |   |   |   |   |   |   |   |   |    |               |                          |                   |                                                                                                                     |                                                                                                                                             |            |                |       |        |   |   |   |   |                                                                                                   |                                                                                                                                  |           |                        |                    |   |   |   |   |   |   |   |   |   |   |                  |                      |    |   |    |   |   |   |   |   |   |                        |                                                                                                                                        |                                                                                                                         |                                                                                                                                                                                                      |                                                                                                                                                                                                                                 |                                     |       |                                                                          having
#  |   |   |   |   |   |   |   |   |   |    |               |                          |                   |                                                                                                                     |                                                                                                                                             |            |                |       |        |   |   |   |   |                                                                                                   |                                                                                                                                  |           |                        |                    |   |   |   |   |   |   |   |   |   |   |                  |                      |    |   |    |   |   |   |   |   |   |                        |                                                                                                                                        |                                                                                                                         |                                                                                                                                                                                                      |                                                                                                                                                                                                                                 |                                     |       |         ___________________________________________________________________|________________________________________________________________________________________________________________________________________________________________________________________________
# ...
#  |   |   |   |   |   |   |   |   |   |    |            knowing                      she                  |   |   |   |   |   |   |   |   |    |     |     |   |   |   |   |   |   |   |   |   |   |   |   |   |   |                         bit                                                        held                                  |    |       the         |      |   |   |    |       the      |       |        |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |       |       |   |   |   |   |   |   |   |   |   |   |   |   |    |     |   |   |   |     |     |       |             '                       yelp                                  |          the                       |                    |   |   |   |   |   |   |   |   |   |   |               believe                   |    |   |    |   |   |   |   |   |   |   |   |   |                dodged                         |   |   |              thistle                  |   |   |     |     |   |   |   |    |   |   |   |    |    |   |   |   |   |   |    |   |   |   |   |   |   |        |            |                the            |       |     |      '   |   |   |   |   |   |   |   |   |   |   |   |   |   |    |    |       |        |        the      |   |   |   |   |   |   |   |          rush              |   |   |    |    |      the      |    |   |   |   |   |   |   |   |   |     |     |   |   |   |   |   |        |                   heels              |   |   |   |   |   |           hurry                  |           |   |   |                               Alice                                   |       |        |   |    |   |                               game                                                  |   |   |   |   |   |   |   |   |   |   |   |   |   |   |        |       |        |        |   |   |                    moment                        |   |   |   |   |   |   |   |        |                            feet                  |   |   |        |                               the                                    |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |    |    |   |   |    |       the          |       |   |   |   |       |                     charges                        |        the             running                     little                 |      |   |               |                |   |   |   |   |   |   |   |   |   |   |   |   |       |           |            |        |   |     |     |   |     |      |   |   |      the      |   |   |    |    |   |   |       '           |   |   |   |   |   |   |   |   |   |   |       |           |                            way                   |   |   |   |   |   |   |   |   |       |        |   |    |   |   |   |   |   |   |   |   |   |   |   |    |       |          out                |            |            |   |                  great                                   |
#  |   |   |   |   |   |   |   |   |   |    |      _________|_________      ___________|___                |   |   |   |   |   |   |   |   |    |     |     |   |   |   |   |   |   |   |   |   |   |   |   |   |   |    ______________________|__________________________         _______________________|____________________________        |    |     ___|___       |      |   |   |    |     ___|___    |       |        |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   